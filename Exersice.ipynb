# %% [markdown]
# <a href="https://colab.research.google.com/github/faboob/Unterrichtuebung/blob/main/Exersice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import read
import pandas as pd
pd.set_option('display.max_rows', None)
data = pd.read_csv('/average-monthly-surface-temperature.csv')
#print(data)
land = "Switzerland"
data_land = data[data['Entity'] == land]

# Ergebnis anzeigen
print(data_land)
# Out:
#              Entity Code  year         Day  Average surface temperature  \
# 173400  Switzerland  CHE  1940  1940-01-15                   -10.516214
# 173401  Switzerland  CHE  1940  1940-02-15                    -4.646474
# 173402  Switzerland  CHE  1940  1940-03-15                    -1.038268
# 173403  Switzerland  CHE  1940  1940-04-15                     3.142060
# 173404  Switzerland  CHE  1940  1940-05-15                     7.324263
# 173405  Switzerland  CHE  1940  1940-06-15                    10.770754
# 173406  Switzerland  CHE  1940  1940-07-15                    12.061514
# 173407  Switzerland  CHE  1940  1940-08-15                    11.631165
# 173408  Switzerland  CHE  1940  1940-09-15                     9.774350
# 173409  Switzerland  CHE  1940  1940-10-15                     5.035296
# 173410  Switzerland  CHE  1940  1940-11-15                    -0.905984
# 173411  Switzerland  CHE  1940  1940-12-15                   -10.385147
# ...
